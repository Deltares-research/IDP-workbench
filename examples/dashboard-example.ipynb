# %% [markdown]
# ## Python functionalities

# %%
import pandas as pd
from pathlib import Path
import solara
import matplotlib.pyplot as plt
import folium
import folium.plugins
import solara

def crime_filter(df, district_values, category_values):
    df_dist = df.loc[df["PdDistrict"].isin(district_values)]
    df_category = df_dist.loc[df_dist["Category"].isin(category_values)]
    return df_category

def crime_charts(df):
    cat_unique = df["Category"].value_counts()
    cat_unique = cat_unique.reset_index()

    dist_unique = df["PdDistrict"].value_counts()
    dist_unique = dist_unique.reset_index()

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

    ax1.bar(cat_unique["Category"], cat_unique["count"])
    ax1.set_title("Amount of Criminal Case Based on Category")
    ax2.bar(dist_unique["PdDistrict"], dist_unique["count"])
    ax2.set_title("Amount of Criminal Case in Selected District")

    display(fig)
    plt.close(fig)

def crime_map(df):
    latitude = 37.77
    longitude = -122.42

    sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

    incidents = folium.plugins.MarkerCluster().add_to(sanfran_map)

    # loop through the dataframe and add each data point to the mark cluster
    for (
        lat,
        lng,
        label,
    ) in zip(df.Y, df.X, df.Category):
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=label,
        ).add_to(incidents)

    # show map
    display(sanfran_map)


path = r'C:\Users\fuentesm\Projects\IDP\Data\Input\Geodata\solara\SF_crime_sample\SF_crime_sample.csv'
df_crime = pd.read_csv(path)

df_crime["Category"] = df_crime["Category"].str.title()
df_crime["PdDistrict"] = df_crime["PdDistrict"].str.title()
df_crime

dff_crime = crime_filter(df_crime, ["Bayview", "Northern"], ["Vandalism", "Assault", "Robbery"])
crime_charts(dff_crime)
crime_map(dff_crime.iloc[0:50, :])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7c3336da01dcb3552f484aad4fbae0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7c3336da01dcb3552f484aad4fbae0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7c3336da01dcb3552f484aad4fbae0b = L.map(
#                 &quot;map_e7c3336da01dcb3552f484aad4fbae0b&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_655442bff39bf87d2a385a6401061bea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_655442bff39bf87d2a385a6401061bea.addTo(map_e7c3336da01dcb3552f484aad4fbae0b);
#
#
#             var marker_cluster_bf59b81b6a78b39fbdd098ab7ad75fe5 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_106e5c94d5a7d2106cc15bf4790ae966 = L.marker(
#                 [37.8016108699901, -122.441398221863],
#                 {}
#             ).addTo(marker_cluster_bf59b81b6a78b39fbdd098ab7ad75fe5);
#
#
#         var popup_e1e6f55670a2a893a5a6cafde7ff74a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3416a34b10215d6e60546150eb38f08c = $(`&lt;div id=&quot;html_3416a34b10215d6e60546150eb38f08c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Assault&lt;/div&gt;`)[0];
#                 popup_e1e6f55670a2a893a5a6cafde7ff74a5.setContent(html_3416a34b10215d6e60546150eb38f08c);
#
#
#
#         marker_106e5c94d5a7d2106cc15bf4790ae966.bindPopup(popup_e1e6f55670a2a893a5a6cafde7ff74a5)
#         ;
#
#
#
#
#             var marker_37384894c8d09c4815fb837b6cded80f = L.marker(
#                 [37.773037747039, -122.430630284155],
#                 {}
#             ).addTo(marker_cluster_bf59b81b6a78b39fbdd098ab7ad75fe5);
#
#
#         var popup_93c4659bedc9a1ca92a282ad58200cc4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91febc82fc59ef1c009ddad23b3fc3d4 = $(`&lt;div id=&quot;html_91febc82fc59ef1c009ddad23b3fc3d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Assault&lt;/div&gt;`)[0];
#                 popup_93c4659bedc9a1ca92a282ad58200cc4.setContent(html_91febc82fc59ef1c009ddad23b3fc3d4);
#
#
#
#         marker_37384894c8d09c4815fb837b6cded80f.bindPopup(popup_93c4659bedc9a1ca92a282ad58200cc4)
#         ;
#
#
#
#
#             var marker_41e67c74295059c276689d6ea53b5bf1 = L.marker(
#                 [37.789163624599794, -122.431378676586],
#                 {}
#             ).addTo(marker_cluster_bf59b81b6a78b39fbdd098ab7ad75fe5);
#
#
#         var popup_9967d3ce68bb440bddb75b9863aea905 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d0938b00545f0d32cb93b158ca32656 = $(`&lt;div id=&quot;html_1d0938b00545f0d32cb93b158ca32656&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vandalism&lt;/div&gt;`)[0];
#                 popup_9967d3ce68bb440bddb75b9863aea905.setContent(html_1d0938b00545f0d32cb93b158ca32656);
#
#
#
#         marker_41e67c74295059c276689d6ea53b5bf1.bindPopup(popup_9967d3ce68bb440bddb75b9863aea905)
#         ;
#
#
#
#
#             var marker_354fb68c99b28f7f7dfac13e8ba13b4b = L.marker(
#                 [37.7661917267111, -122.400756349771],
#                 {}
#             ).addTo(marker_cluster_bf59b81b6a78b39fbdd098ab7ad75fe5);
#
#
#         var popup_434b4154ea2463a7596f1e7f3e2c5f69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22608170f488c427498f9dcbf1c8d01b = $(`&lt;div id=&quot;html_22608170f488c427498f9dcbf1c8d01b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Assault&lt;/div&gt;`)[0];
#                 popup_434b4154ea2463a7596f1e7f3e2c5f69.setContent(html_22608170f488c427498f9dcbf1c8d01b);
#
#
#
#         marker_354fb68c99b28f7f7dfac13e8ba13b4b.bindPopup(popup_434b4154ea2463a7596f1e7f3e2c5f69)
#         ;
#
#
#
#
#             var marker_3a6d2a9aba6bc4d37f266ee702baefaa = L.marker(
#                 [37.761981795416006, -122.395567457366],
#                 {}
#             ).addTo(marker_cluster_bf59b81b6a78b39fbdd098ab7ad75fe5);
#
#
#         var popup_b97bb526f03b13f22c5cffc8d4283341 = L.popup({&quot;maxWidth&quot;: &quot;10

# %% [markdown]
# ## Solara app

# %% [markdown]
# #### Defining reactive variables

# %%
districts = solara.reactive(
    ["Bayview", "Northern"],
)
categories = solara.reactive(["Vandalism", "Assault", "Robbery"])
limit = solara.reactive(100)

# %% [markdown]
# #### Visualize components

# %%
@solara.component
def View():
    dff = crime_filter(df_crime, districts.value, categories.value)
    row_count = len(dff)
    if row_count > limit.value:
        solara.Warning(f"Only showing the first {limit.value} of {row_count:,} crimes on map")
    crime_map(dff.iloc[: limit.value])
    if row_count > 0:
        crime_charts(dff)
    else:
        solara.Warning("You filtered out all the data, no charts shown")
View()
# Out:
# Cannot show ipywidgets in text

# %% [markdown]
# #### Update variables

# %%
limit.value = 70
districts.value = ["Soutern", "Northern"]

# %% [markdown]
# #### Adding controls

# %%
solara.SelectMultiple("District", all_values=[str(k) for k in df_crime["PdDistrict"].unique().tolist()], values=districts)
# Out:
# Cannot show ipywidgets in text

# %%
@solara.component
def Controls():
    solara.SelectMultiple("District", all_values=[str(k) for k in df_crime["PdDistrict"].unique().tolist()], values=districts)
    solara.SelectMultiple("Category", all_values=[str(k) for k in df_crime["Category"].unique().tolist()], values=categories)
    solara.Text("Maximum number of rows to show on map")
    solara.SliderInt("", value=limit, min=1, max=1000)

Controls()
# Out:
# Cannot show ipywidgets in text

# %% [markdown]
# #### Update variables though the python code

# %%
# Note that we can read AND write reactive variables
categories.value = [*categories.value, "Warrants"]

# %% [markdown]
# #### Combining the components

# %%
@solara.component
def Page():
    with solara.Sidebar():
        Controls()
    View()


Page()
# Out:
# Cannot show ipywidgets in text
